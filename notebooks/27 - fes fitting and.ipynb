# %%
import torch
from torch.distributions import MultivariateNormal
import numpy as np
import matplotlib.pyplot as plt

from flonacomldft.utils.io_utils import get_path

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# loading FES data
file = get_path()+'/unrotated_300.txt'
fes_data = np.loadtxt(file)
fes_data = torch.from_numpy(fes_data)
fes_data = fes_data.float().requires_grad_(True)

# %%
# Out:
# tensor([[ 8.5893,  2.1891, -0.4155],
#         [ 8.6007,  2.1882, -0.4127],
#         [ 8.6122,  2.1873, -0.4099],
#         ...,
#         [13.1886,  2.3129, -0.0337],
#         [13.2001,  2.3120, -0.0316],
#         [13.2116,  2.3112, -0.0295]], requires_grad=True)
