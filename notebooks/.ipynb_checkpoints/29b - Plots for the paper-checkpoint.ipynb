# %% [markdown]
# # Plots for the paper

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pylab as pylab

size=24
params = {'legend.fontsize': size,
          'figure.figsize': (15, 5),
         'axes.labelsize': size,
         'axes.titlesize': size,
         'xtick.labelsize': size,
         'ytick.labelsize': size}

pylab.rcParams.update(params)

# %%
# get minima structure configurations
from flonacomldft.utils.silver_isomers_utils import get_molecule_isomer_minima
from flonacomldft.utils.plots import plot_energy_surface
from ase.visualize.plot import plot_atoms

ag6_is0 = get_molecule_isomer_minima(name="is0")
ag6_is1 = get_molecule_isomer_minima(name="is1")

ag6_is0.center()
ag6_is1.center()

ag6_is0.translate([4, 0, 0])
ag6_is1.translate([11, 7, 7])

# %%
# load adaptive simulations
from flonacomldft.utils.io_utils import load_pickle_file
from flonacomldft.utils.plots import set_plot_sequential_data
from flonacomldft.utils.diagnostics import avg_windows

path = "/mnt/home/amolina/ceph/ADAPTIVE-DFT/1-adaptive/results_2"
simulations = ["results_adaptive_is0_25072550/adaptive_sampling_is0_25072550.pkl",
              "results_adaptive_is1_25072551/adaptive_sampling_is1_25072551.pkl"]

adaptives = [load_pickle_file(simulations[i], path) for i in range(0, 2)]

# %%
accs_per_adaptive = []

for i in range(0, 2):
    accs = torch.cat(adaptives[i]["accs"])
    accs_per_adaptive.append(accs.mean(dim=1))

# %%
xs_per_adaptive = []
us_per_adaptive = []

for i in range(0, 2):
    xs = torch.cat(adaptives[i]["xs"])
    us = torch.cat(adaptives[i]["us"])
    
    xs_per_adaptive.append(xs)
    us_per_adaptive.append(us)
    
isomers_label = ["Planar", "Bipyramidal"]
energies_flatten = [energy.flatten().detach() for energy in us_per_adaptive]
energies = dict(zip(isomers_label, energies_flatten))

# %%
adaptives[i].keys()
# Out:
# dict_keys(['dict_flows_training', 'mcmc_runs', 'xs', 'us', 'accs', 'isomers', 'time_flow', 'time_adaptive', 'args'])

# %%
flow_models = [adaptives[i]["dict_flows_training"][-1][0]["model"] for i in range(0, 2)]

nlls = [flow_models[i].nll(xs_per_adaptive[i][:, 0]).detach().numpy() for i in range(2)]

# %%
fig, axs =  plt.subplots(3, 2, figsize=(19, 24))

colors = ["blue", "orange"]

plot_atoms(ag6_is0, ax=axs[0][0], rotation="-20x, 30y, 0z")
plot_atoms(ag6_is1, ax=axs[0][0], rotation="-20x, 30y, 0z")

#===

plot_energy_surface(fig=fig, ax=axs[0][1])

#====

axs[1][0].scatter(us_per_adaptive[1][:, 0].detach().numpy(), nlls[1], c=np.arange(0, 600, 1))
axs[1][0].set_ylabel("Negative log likelihood [u.a]")
axs[1][0].set_xlabel("Potential energy [e.V]")

#====

sns.histplot(energies, ax=axs[1][1], kde=True, stat="density", color=colors, bins=20)
axs[1][1].set_xlabel("Potential energy [e.V]")

#====

for i in range(0, 2):
    set_plot_sequential_data(accs_per_adaptive[i], 
                             avg=True, 
                             window_size=50, 
                             color=colors[i], 
                             ax=axs[2][0], 
                             linewidth=2.5, 
                             alpha=0.1)

axs[2][0].set_ylabel("Acceptance ratio")
axs[2][0].set_xlabel("MCMC steps")

#====

axs[2][1].set_ylabel("Participation ratio")
axs[2][1].set_xlabel("MCMC steps")
# Out:
# Text(0.5, 0, 'MCMC steps')

# %%
# Do horizontal plot
# Do vertical plot
# R hat plot with internal coordinates
# Do second plot, with multimodal sampling

# %%
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(34, 16), gridspec_kw={'width_ratios': [1.6, 1, 1]})
gs = axs[0, 0].get_gridspec()
# remove the underlying axes
for ax in axs[0:, 0]:
    ax.remove()
    
    
axbig = fig.add_subplot(gs[0:, :1])
#axbig.annotate('Big Axes \nGridSpec[1:, -1]', (0.1, 0.5),
               #xycoords='axes fraction', va='center')

plot_energy_surface(fig=fig, ax=axbig)

#====

axs[0][2].scatter(us_per_adaptive[1][:, 0].detach().numpy(), nlls[1], c=np.arange(0, 600, 1))
axs[0][2].set_ylabel("Negative log likelihood [u.a]")
axs[0][2].set_xlabel("Potential energy [e.V]")

#====

sns.histplot(energies, ax=axs[0][1], kde=True, stat="density", color=colors, bins=20)
axs[0][1].set_xlabel("Potential energy [e.V]")

#====

for i in range(0, 2):
    set_plot_sequential_data(accs_per_adaptive[i], 
                             avg=True, 
                             window_size=50, 
                             color=colors[i], 
                             ax=axs[1][1], 
                             linewidth=2.5, 
                             alpha=0.1)

axs[1][1].set_ylabel("Acceptance ratio")
axs[1][1].set_xlabel("MCMC steps")

#====

axs[1][2].set_ylabel("Participation ratio")
axs[1][2].set_xlabel("MCMC steps")
# Out:
# Text(0.5, 0, 'MCMC steps')
