# %%
from flonacomldft.utils.io_utils import load_pickle_file, get_path
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
init_flow = load_pickle_file("berendsen/models/is0_flow_dic_training_20230520201411.pkl", get_path())

# %%
losses = init_flow["losses"]
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.plot(losses[0], label="train")
ax.plot(losses[1], label="test")
ax.legend()
ax.set_xlabel('Iterations')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
adapt = load_pickle_file("adaptative_sampling_2406684.pkl", path="/mnt/home/amolina/ceph/simulations/adaptive_samp_1/")

# %%
from flonacomldft.utils.diagnostics import avg_windows
from flonacomldft.utils.plots import set_plot_iteration

# %%
n_chains = adapt['args']['n_chains']

# %%
accs = torch.stack(adapt['accs'])
accs_flatten = accs.reshape(-1, n_chains)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6) )
i=0
for acc in accs:
    set_plot_iteration(acc.mean(dim=1), avg=False, window_size=10, axis=1, ax=ax, init=i)
    if i > 0:
        i += acc.shape[0]
    else:
        i += acc.shape[0]

window_size = 10
axis = 1

x_avg = np.arange(len(avg_windows(accs_flatten.mean(dim=1), window_size, axis)))
y_avg = avg_windows(accs_flatten.mean(dim=1), window_size, axis)
ax.plot(x_avg, y_avg, color="k", label='average')

ax.set_xlabel('Steps')
ax.set_ylabel('Acceptance')
ax.legend()

# %%
dict_flows_training = adapt['dict_flows_training']
len(dict_flows_training[0])
# Out:
# 1

# %%
for j in range(1):

    losses_train = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][0]) for i in range(len(dict_flows_training))])
    losses_test = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][1]) for i in range(len(dict_flows_training))])

    y_lines = np.cumsum([len(dict_flows_training[i][j]['losses'][0]) for i in range(len(dict_flows_training))])

    fig, ax = plt.subplots(1, 1, figsize=(12,6) )
    set_plot_iteration(losses_train, avg=False, window_size=10, axis=0, alpha=1, ax=ax, label='train')
    set_plot_iteration(losses_test, avg=False, window_size=10, axis=0,alpha=1, ax=ax, label='test')

    ax.vlines(y_lines, ymin=torch.log(losses_train.min()), ymax=torch.log(losses_train.max()), color='k', alpha=0.2, linestyle='--')

    ax.set_xlabel('Steps')
    ax.set_ylabel('Loss')
    ax.set_label(['train', 'test'])
    ax.legend()

    ax.set_title('Flow {}'.format(j))

# %%
# new adapt results

# %%
adapt_2 = load_pickle_file('adaptative_sampling_2419701.pkl',
    path='/mnt/home/amolina/ceph/simulations/adaptive_samp_5/results_adaptive_is0_2419701')

# %%
adapt_2.keys()
# Out:
# dict_keys(['dict_flows_training', 'mcmc_runs', 'xs', 'us', 'accs', 'isomers', 'args'])

# %%
dic_flows = adapt_2['dict_flows_training']

# %%
part_ratios = [dic_flows[i][0]['part_ratios'] for i in range(1, 96, 5)]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
i=0
for part_ratio in part_ratios:
    set_plot_iteration(part_ratio, avg=False, window_size=10, axis=0, alpha=1, ax=ax, label='', init=i, marker='o')
    i+=len(part_ratio)

set_plot_iteration(torch.cat(part_ratios).flatten().detach(), avg=True, window_size=20, axis=1, alpha=0.3, ax=ax, label='part_ratio', init=0, linewidth=3)
ax.legend()
ax.set_xlabel('Number of MCMC simulations')
ax.set_ylabel('Participation ratio')
# Out:
# Text(0, 0.5, 'Participation ratio')

# %%
n_chains = adapt_2['args']['n_chains']

# %%
accs = torch.stack(adapt_2['accs'])
accs_flatten = accs.reshape(-1, n_chains)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6) )
i=0
for acc in accs:
    set_plot_iteration(acc.mean(dim=1), avg=False, window_size=10, axis=1, ax=ax, init=i)
    if i > 0:
        i += acc.shape[0]
    else:
        i += acc.shape[0]

window_size = 10
axis = 1

x_avg = np.arange(len(avg_windows(accs_flatten.mean(dim=1), window_size, axis)))
y_avg = avg_windows(accs_flatten.mean(dim=1), window_size, axis)
ax.plot(x_avg, y_avg, color="k", label='average')

ax.set_xlabel('MCMC Steps')
ax.set_ylabel('Acceptance')
ax.legend()

# %%
dict_flows_training = adapt_2['dict_flows_training']
len(dict_flows_training)
# Out:
# 101

# %%
for j in range(1):

    losses_train = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][0]) for i in range(len(dict_flows_training))])
    losses_test = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][1]) for i in range(len(dict_flows_training))])

    y_lines = np.cumsum([len(dict_flows_training[i][j]['losses'][0]) for i in range(len(dict_flows_training))])

    fig, ax = plt.subplots(1, 1, figsize=(12,6) )
    set_plot_iteration(losses_train, avg=False, window_size=10, axis=0, alpha=1, ax=ax, label='train')
    set_plot_iteration(losses_test, avg=False, window_size=10, axis=0,alpha=1, ax=ax, label='test')

    ax.vlines(y_lines, ymin=torch.log(losses_train.min()), ymax=torch.log(losses_train.max()), color='k', alpha=0.2, linestyle='--')

    ax.set_xlabel('Iterations (training)')
    ax.set_ylabel('Loss')
    ax.set_label(['train', 'test'])
    ax.legend()

    ax.set_title('Flow {}'.format(j))
    ax.set_xlim(49500, 52000)
# Out:
# /tmp/ipykernel_2162399/1809177932.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   losses_train = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][0]) for i in range(len(dict_flows_training))])
# /tmp/ipykernel_2162399/1809177932.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   losses_test = torch.cat([torch.tensor(dict_flows_training[i][j]['losses'][1]) for i in range(len(dict_flows_training))])

# %%
## compute particiation ratio

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from ase.io import read

# %%
path_dft = '/mnt/home/amolina/ceph/simulations/adaptive_samp_5/results_adaptive_is0_2419701/DFTAdaptive'

# %%
ag6s = [read(path_dft+'/ag6_1_{:d}_{:d}.out'.format(i, j)) for j in range(25) for i in range(5)]

# %%
us = [ag6.get_potential_energy() for ag6 in ag6s]

# %%
from flonacomldft.internal_coordinates import Coordinates_mapping

# %%
coord_mapping = Coordinates_mapping()

# %%
zmat = coord_mapping.get_internal_from_trajectory(ag6s, isomer=0, temperature=300)

# %%
zmat
# Out:
# tensor([[ 2.7980,  2.6642,  2.7796,  ..., -6.8798,  0.0000,  9.4693],
#         [ 2.7859,  2.6615,  2.7831,  ..., -6.8752,  0.0000,  9.4457],
#         [ 2.7953,  2.6741,  2.7840,  ..., -6.8812,  0.0000,  9.4585],
#         ...,
#         [ 2.8165,  2.6740,  2.7657,  ..., -6.8773,  0.0000,  9.4504],
#         [ 2.7818,  2.6820,  2.7945,  ..., -6.8787,  0.0000,  9.4406],
#         [ 2.7836,  2.6768,  2.7848,  ..., -6.8808,  0.0000,  9.4470]],
#        dtype=torch.float64, grad_fn=<StackBackward0>)

# %%
xs, logdetjac_xs, us_xs  = coord_mapping.get_real_centered_from_internal(zmat[:, :12], logdetjacs=zmat[:, 14], isomer=0, energies=zmat[:, 12])

# %%
from ase.units import kB

# %%
model = dict_flows_training[1][0]['model']

# %%
log_weight = (us_xs/(kB * 300)).squeeze() - model.nll(xs.float())

# %%
log_ratio = torch.logsumexp(2 * log_weight, dim=0) - 2 * torch.logsumexp(log_weight, dim=0)

# %%
torch.exp(-log_ratio) / xs.shape[0]
# Out:
# tensor(0.0333, dtype=torch.float64, grad_fn=<DivBackward0>)

# %%
def get_part_ratio(traj, model, isomer):
    
    us = [molecule.get_potential_energy() for molecule in traj]
    zmat = coord_mapping.get_internal_from_trajectory(traj, isomer=0, temperature=300)
    xs, logdetjac_xs, us_xs  = coord_mapping.get_real_centered_from_internal(zmat[:, :12], 
                                                                             logdetjacs=zmat[:, 14], 
                                                                             isomer=0, 
                                                                             energies=zmat[:, 12])
    log_weight = (us_xs/(kB * 300)).squeeze() - model.nll(xs.float())
    log_ratio = torch.logsumexp(2 * log_weight, dim=0) - 2 * torch.logsumexp(log_weight, dim=0)
    
    return torch.exp(-log_ratio) / xs.shape[0]

# %%
ag6s = [[read(path_dft+'/ag6_{:d}_{:d}_{:d}.out'.format(k, i, j)) for j in range(25) for i in range(5)]
       for k in range(1, 96, 5)]

models = [dict_flows_training[k][0]['model'] for k in range(1, 96, 5)]

# %%
len(ag6s)
# Out:
# 19

# %%
part_ratios = []

for ag6, model in zip(ag6s, models):
    part_ratio = get_part_ratio(ag6, model, 0)
    part_ratios.append(part_ratio)

# %%
plt.figure(figsize=(10, 6))
plt.plot(torch.tensor(part_ratios), '--o')
plt.xlabel('Number of MCMC simulations')
plt.ylabel('Participation ratio')
# Out:
# Text(0, 0.5, 'Participation ratio')
